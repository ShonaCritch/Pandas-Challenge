# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
y_bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, y_bars_in_cities, color="b", align="center")
# Out:
# <img src="data:image/png;base64,..." width="639.8648566186124">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
name_graphbar = [value for value in x_axis]
plt.xticks(name_graphbar, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x25a8ff84850>,
# ...
#  [Text(-1.0, 0, 'New Orleans'),
#   Text(0.0, 0, 'Milwaukee'),
#   Text(1.0, 0, 'Omaha'),
#   Text(2.0, 0, 'Pittsburgh'),
#   Text(3.0, 0, 'Toledo')])

# %%
# Set the limits of the x axis to give 0.75 on each side of bars
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis, eyeball for the largest number and set to round up
plt.ylim(0, max(bars_in_cities)+0.4)
# Out:
# (0.0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bars Per 10,000 Households")
# Out:
# Text(82.66389012336731, 0.5, 'Bars Per 10,000 Households')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("../Images/BarDensity.png")
plt.show()
